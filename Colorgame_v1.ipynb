# %%
import os
import numpy as np
from typing import Optional

from gymnasium import Env
from gymnasium.spaces import MultiDiscrete, Box, Discrete
from gymnasium.error import DependencyNotInstalled

from randomcolors import colors_array

from stable_baselines3 import PPO, A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
from sb3_contrib import RecurrentPPO

# %%
class GameEnv(Env):
    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 10,
    }
    
    def __init__(self, num_cubes=3):
        self.num_cubes = num_cubes
        
        # Define the colors for each face of the cube
        self.color_map = ['red', 'green', 'blue', 'white', 'yellow', 'pink']
        # Create a color-to-index mapping
        self.color_to_index = {color: i for i, color in enumerate(self.color_map)}   
        
        # Define the action space
        self.action_space = MultiDiscrete(np.array([2] * len(self.color_map), dtype=np.uint8))
        # Define the Box observation space
        self.observation_space = Box(
            low=np.zeros(self.num_cubes),
            high= np.full(self.num_cubes, len(self.color_map)), dtype=np.uint8)
        
        self.shuffled_color = self.color_shuffle()
        
        self.player_credit = 10
        self.step_count = 100
        
    def step(self, action):
        
        self.step_count -= 1
        
        assert self.action_space.contains(action)
        # Get selected colors
        selected_color = [self.color_map[i] for i, selected in enumerate(action) if selected]
        selected_color_to_index = np.array([self.color_to_index[color] for color in selected_color]).astype(np.uint8)

        # Re-Roll cubes every step
        self.cubes = self.roll_cube(self.shuffled_color)
        
        # Return the count of color that match to selected and observation space
        cubes = np.array([self.color_to_index[color] for color in self.cubes]).astype(np.uint8)
        counted_occurences = {idx: np.count_nonzero(cubes == idx) for idx in selected_color_to_index}

        win = sum(counted_occurences.values())
        loss = -len(set(selected_color).difference(self.cubes))
        
        total = win + loss

        self.player_credit += total

        if total == 3 and win == 3 and self.player_credit > 10:
            reward = 1.5
        elif total >= 1 and not self.player_credit < 0:
            reward = 1.0
        elif total == 0:
            reward = 0.0
        else:
            reward = -1.0

        # every 100 step, game will reset
        if self.step_count == 0 or self.player_credit == 0:
            done = True
        else:
            done = False
            
        info = {
            'selected_color': selected_color,
            'occurences_count': counted_occurences, 
            'win_count': win, 
            'loss_count': loss, 
            'total_count': total,
            'credit_count': self.player_credit
        }
        return self._get_obs(), reward, done, False, info

    def _get_obs(self):
        return np.array([self.color_to_index[color] for color in self.cubes]).astype(np.uint8)

    def color_shuffle(self):
        return np.array(colors_array[self.np_random.choice(719)])
        
    def roll_cube(self, shuffled_colors):
        return np.array([
            self.np_random.choice(shuffled_colors), 
            self.np_random.choice(shuffled_colors), 
            self.np_random.choice(shuffled_colors)
        ])
        
    def reset(
        self,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):
        super().reset(seed=seed)
        self.player_credit = 10
        self.step_count = 100
        self.shuffled_color = self.color_shuffle()
        self.cubes = self.roll_cube(self.shuffled_color)
        
        return self._get_obs(), {}

# %%
env = GameEnv()
env.reset(seed=42)
# Out:
# (array([0, 5, 3], dtype=uint8), {})

# %%
timesteps=1500000

# %%
log_path = os.path.join("training", "logs")
model_path = os.path.join("training", "models/{}{}".format("PPO_", timesteps))

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=1000,
                             best_model_save_path=model_path,
                             verbose=1
                            )

# %%
# model = A2C('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

# %%
# model = RecurrentPPO('MlpLstmPolicy', env, verbose=1, tensorboard_log=log_path)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=timesteps)
# Out:
# Logging to training/logs/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -8.11    |
# | time/              |          |
# |    fps             | 1937     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | -9.18       |
# | time/                   |             |
# |    fps                  | 1602        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009448185 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | -0.00342    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 1510        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009694154 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | -0.00231    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.96        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 18.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -9.93        |
# | time/                   |              |
# |    fps                  | 1456         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0075279195 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | -0.00201     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.22         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00601     |
# |    value_loss           | 18.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 1391        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007631688 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | -0.00183    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | -9.69       |
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007053295 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | -0.00325    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 1376        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008679187 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | -0.000666   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.71        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | -9.99       |
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008266792 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.000183    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00835    |
# |    value_loss           | 22.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | -9.09       |
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008844847 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.00222     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00596    |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.14       |
# | time/                   |             |
# |    fps                  | 1374        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008792954 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | -0.00498    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.45        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.3       |
# |    ep_rew_mean          | -9.04      |
# | time/                   |            |
# |    fps                  | 1370       |
# |    iterations           | 11         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00837384 |
# |    clip_fraction        | 0.0916     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.08      |
# |    explained_variance   | -0.00318   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.91       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0081    |
# |    value_loss           | 15.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.5        |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008392008 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.000152    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 22.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.8        |
# |    ep_rew_mean          | -9.8        |
# | time/                   |             |
# |    fps                  | 1362        |
# |    iterations           | 13          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008845331 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | -0.00495    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.92        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.5         |
# |    ep_rew_mean          | -7.37        |
# | time/                   |              |
# |    fps                  | 1359         |
# |    iterations           | 14           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0084772855 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.06        |
# |    explained_variance   | -0.00153     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00807     |
# |    value_loss           | 25.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.2         |
# |    ep_rew_mean          | -8.01        |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 15           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0107634775 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.04        |
# |    explained_variance   | -0.00142     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.15         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00844     |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.2        |
# |    ep_rew_mean          | -7.19       |
# | time/                   |             |
# |    fps                  | 1359        |
# |    iterations           | 16          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010185344 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.00258     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.48        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00972    |
# |    value_loss           | 18.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | -8.24       |
# | time/                   |             |
# |    fps                  | 1357        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009229911 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5           |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00697    |
# |    value_loss           | 7.98        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.5         |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 18           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0075988723 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.05        |
# |    explained_variance   | -3.49e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00738     |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.4         |
# |    ep_rew_mean          | -12.2        |
# | time/                   |              |
# |    fps                  | 1343         |
# |    iterations           | 19           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0083174035 |
# |    clip_fraction        | 0.0909       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.03        |
# |    explained_variance   | 0.00142      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00777     |
# |    value_loss           | 26.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.6        |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010612312 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | -0.00479    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.7         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 21.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.9         |
# |    ep_rew_mean          | -9.4         |
# | time/                   |              |
# |    fps                  | 1344         |
# |    iterations           | 21           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0078021227 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.01        |
# |    explained_variance   | 0.000169     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.5          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00587     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | -7.37       |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011052226 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | -0.00221    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.42        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | -8.64       |
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 23          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008068196 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.00118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.5         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | -8.88       |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 24          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007942165 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | -0.00203    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -11         |
# | time/                   |             |
# |    fps                  | 1339        |
# |    iterations           | 25          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011218103 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | -0.00056    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.72        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.8        |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 26          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007777827 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | -0.00277    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.5         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 20.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.1         |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 1336         |
# |    iterations           | 27           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0095200855 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.89        |
# |    explained_variance   | -0.00262     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.26         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00865     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.1        |
# |    ep_rew_mean          | -8.66       |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 28          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009604024 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | -0.00218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.47        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.9        |
# |    ep_rew_mean          | -6.82       |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 29          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009840989 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | -0.00425    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 6.75        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.6       |
# |    ep_rew_mean          | -6.92      |
# | time/                   |            |
# |    fps                  | 1337       |
# |    iterations           | 30         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00793165 |
# |    clip_fraction        | 0.0963     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.9       |
# |    explained_variance   | -0.0013    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.85       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00708   |
# |    value_loss           | 14.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | -8.21       |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 31          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008863063 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | -0.000644   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.6         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00972    |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.6        |
# |    ep_rew_mean          | -9.1        |
# | time/                   |             |
# |    fps                  | 1337        |
# |    iterations           | 32          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009158526 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | -0.00521    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.65        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | -8.3        |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 33          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008579396 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | -0.000414   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.6        |
# |    ep_rew_mean          | -6.75       |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 34          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008167681 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | -0.0019     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00784    |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | -6.01       |
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 35          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009203457 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | -0.00164    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.33        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0086     |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.1        |
# |    ep_rew_mean          | -5.51       |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 36          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009885989 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.000271    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.3         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.5        |
# |    ep_rew_mean          | -7.82       |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 37          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008232327 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | -0.00051    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -8.62       |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 38          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009330192 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | -0.00225    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 16.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.6         |
# |    ep_rew_mean          | -7.82        |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 39           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0091410335 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.81        |
# |    explained_variance   | -0.00195     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.89         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00745     |
# |    value_loss           | 12           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | -7.13       |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 40          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009183421 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | -0.00102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.98        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 14.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | -8.78       |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 41          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010036068 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.000892    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.83        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.5        |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 42          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009653233 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | -0.000268   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.35        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.9        |
# |    ep_rew_mean          | -9.01       |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 43          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010327737 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.000807    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 19.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.1        |
# |    ep_rew_mean          | -8.21       |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 44          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008539826 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | -0.0011     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 9           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.9        |
# |    ep_rew_mean          | -7.02       |
# | time/                   |             |
# |    fps                  | 1327        |
# |    iterations           | 45          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008928396 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | -0.000371   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.35        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0075     |
# |    value_loss           | 18          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54          |
# |    ep_rew_mean          | -8.07       |
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 46          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011440458 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | -0.0034     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.37        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 8.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.6        |
# |    ep_rew_mean          | -7.47       |
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 47          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010925176 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | -0.00126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 18.2        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 55.7      |
# |    ep_rew_mean          | -7.51     |
# | time/                   |           |
# |    fps                  | 1311      |
# |    iterations           | 48        |
# |    time_elapsed         | 74        |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0088029 |
# |    clip_fraction        | 0.104     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.68     |
# |    explained_variance   | -0.000302 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 10.2      |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.00712  |
# |    value_loss           | 13.1      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | -7.07       |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 49          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007297625 |
# |    clip_fraction        | 0.0994      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | -0.00388    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00944    |
# |    value_loss           | 8.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.7        |
# |    ep_rew_mean          | -7.29       |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 50          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008661878 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | -8.27       |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 51          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007632981 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.000939    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.54        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 12.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.8       |
# |    ep_rew_mean          | -9.46      |
# | time/                   |            |
# |    fps                  | 1309       |
# |    iterations           | 52         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01038198 |
# |    clip_fraction        | 0.0986     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.63      |
# |    explained_variance   | -0.000943  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.42       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00753   |
# |    value_loss           | 12.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.3        |
# |    ep_rew_mean          | -7.14       |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 53          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008864373 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | -0.00059    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.96        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52          |
# |    ep_rew_mean          | -7.12       |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 54          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.008463188 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | -7.55e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 9.69        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.2       |
# |    ep_rew_mean          | -8.68      |
# | time/                   |            |
# |    fps                  | 1307       |
# |    iterations           | 55         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.01097382 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | -0.000931  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.59       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 9.82       |
# ...
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.9        |
# |    ep_rew_mean          | -9.26       |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 716         |
# |    time_elapsed         | 1207        |
# |    total_timesteps      | 1466368     |
# | train/                  |             |
# |    approx_kl            | 0.012673367 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.00195    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.26        |
# |    n_updates            | 7150        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 14.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.7         |
# |    ep_rew_mean          | -8.95        |
# | time/                   |              |
# |    fps                  | 1214         |
# |    iterations           | 717          |
# |    time_elapsed         | 1209         |
# |    total_timesteps      | 1468416      |
# | train/                  |              |
# |    approx_kl            | 0.0096216425 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.0004       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.43         |
# |    n_updates            | 7160         |
# |    policy_gradient_loss | -0.015       |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | -8.32       |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 718         |
# |    time_elapsed         | 1211        |
# |    total_timesteps      | 1470464     |
# | train/                  |             |
# |    approx_kl            | 0.009675536 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.00091    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.21        |
# |    n_updates            | 7170        |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 17.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | -8.61       |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 719         |
# |    time_elapsed         | 1212        |
# |    total_timesteps      | 1472512     |
# | train/                  |             |
# |    approx_kl            | 0.009696914 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.000296   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.21        |
# |    n_updates            | 7180        |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 12.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.3        |
# |    ep_rew_mean          | -7.22       |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 720         |
# |    time_elapsed         | 1214        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.010578355 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 7.99e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.44        |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 17.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.6        |
# |    ep_rew_mean          | -6.67       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 721         |
# |    time_elapsed         | 1216        |
# |    total_timesteps      | 1476608     |
# | train/                  |             |
# |    approx_kl            | 0.011535635 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.00691    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97        |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 8.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | -8.34       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 722         |
# |    time_elapsed         | 1218        |
# |    total_timesteps      | 1478656     |
# | train/                  |             |
# |    approx_kl            | 0.009022329 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.00134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 14.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | -9.46       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 723         |
# |    time_elapsed         | 1219        |
# |    total_timesteps      | 1480704     |
# | train/                  |             |
# |    approx_kl            | 0.009720166 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.000118   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.23        |
# |    n_updates            | 7220        |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.9         |
# |    ep_rew_mean          | -7.78        |
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 724          |
# |    time_elapsed         | 1221         |
# |    total_timesteps      | 1482752      |
# | train/                  |              |
# |    approx_kl            | 0.0077397013 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.00177      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.05         |
# |    n_updates            | 7230         |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 19.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.4        |
# |    ep_rew_mean          | -6.49       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 725         |
# |    time_elapsed         | 1223        |
# |    total_timesteps      | 1484800     |
# | train/                  |             |
# |    approx_kl            | 0.008670857 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | -0.00768    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74        |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 11.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.9       |
# |    ep_rew_mean          | -7.53      |
# | time/                   |            |
# |    fps                  | 1213       |
# |    iterations           | 726        |
# |    time_elapsed         | 1225       |
# |    total_timesteps      | 1486848    |
# | train/                  |            |
# |    approx_kl            | 0.01019287 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | -0.0034    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.46       |
# |    n_updates            | 7250       |
# |    policy_gradient_loss | -0.0133    |
# |    value_loss           | 8.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.4        |
# |    ep_rew_mean          | -8.62       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 727         |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 1488896     |
# | train/                  |             |
# |    approx_kl            | 0.008062232 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.0011      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.2         |
# |    n_updates            | 7260        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59          |
# |    ep_rew_mean          | -9.07       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 728         |
# |    time_elapsed         | 1228        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.009429414 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 5.17e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.23        |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 14.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.4        |
# |    ep_rew_mean          | -5.6        |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 729         |
# |    time_elapsed         | 1230        |
# |    total_timesteps      | 1492992     |
# | train/                  |             |
# |    approx_kl            | 0.008889902 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.00294    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.09        |
# |    n_updates            | 7280        |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.9        |
# |    ep_rew_mean          | -5.78       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 730         |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 1495040     |
# | train/                  |             |
# |    approx_kl            | 0.010336022 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | -0.00331    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78        |
# |    n_updates            | 7290        |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 5.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58          |
# |    ep_rew_mean          | -7.16       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 731         |
# |    time_elapsed         | 1234        |
# |    total_timesteps      | 1497088     |
# | train/                  |             |
# |    approx_kl            | 0.010621738 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.68        |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.2        |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 732         |
# |    time_elapsed         | 1235        |
# |    total_timesteps      | 1499136     |
# | train/                  |             |
# |    approx_kl            | 0.011349816 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -0.00218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.86        |
# |    n_updates            | 7310        |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.2        |
# |    ep_rew_mean          | -9.82       |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 733         |
# |    time_elapsed         | 1237        |
# |    total_timesteps      | 1501184     |
# | train/                  |             |
# |    approx_kl            | 0.008822644 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 1.53e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 17.2        |
# -----------------------------------------

# %%
obs, _= env.reset(seed=42)
total_reward = 0
total_credit = 0
loss_count = 0 
for episode in range(99):
    # action = env.action_space.sample()
    action, _ = model.predict(obs)
    obs, reward, done, _, info = env.step(action)

    # print("Game roll : ", obs)
    # print("Occurrences count: {}".format(info['occurences_count']))
    # print("Selected color : {} \n".format(info['selected_color']))
    # print('Win :', info['win_count'])
    # print('Loss :', info['loss_count'])
    # print('Total : {}'.format(info['total_count']))
    # print('Credit: {} \n'.format(info['credit_count']))
    print('Episode {} : Reward {} \n'.format(episode, reward))
    # total_win += info['total_count']
        
    total_reward += reward
    if done:
        print("DONE HEEREE!! \n\n")
        total_credit += info['credit_count']
        loss_count += 1
        env.reset()
        
print('Loss count: {}'.format(loss_count))
# print('Total wins: {} \n'.format(total_win))
print('Total credit: {} \n'.format(total_credit))
print('Reward {} \n'.format(total_reward))
# Out:
# Episode 0 : Reward -1.0
#
# Episode 1 : Reward 1.5
#
# Episode 2 : Reward 0.0
#
# Episode 3 : Reward 1.0
#
# Episode 4 : Reward 1.0
#
# Episode 5 : Reward -1.0
#
# Episode 6 : Reward 1.0
#
# Episode 7 : Reward -1.0
#
# Episode 8 : Reward -1.0
#
# Episode 9 : Reward 0.0
#
# Episode 10 : Reward -1.0
#
# Episode 11 : Reward 1.0
#
# Episode 12 : Reward -1.0
#
# Episode 13 : Reward 1.0
#
# Episode 14 : Reward 0.0
#
# Episode 15 : Reward 1.0
#
# Episode 16 : Reward -1.0
#
# Episode 17 : Reward -1.0
#
# Episode 18 : Reward 1.0
#
# Episode 19 : Reward -1.0
#
# Episode 20 : Reward 0.0
#
# Episode 21 : Reward -1.0
#
# Episode 22 : Reward 1.0
#
# Episode 23 : Reward 0.0
#
# Episode 24 : Reward -1.0
#
# Episode 25 : Reward 0.0
#
# Episode 26 : Reward 1.0
#
# Episode 27 : Reward 0.0
#
# Episode 28 : Reward -1.0
#
# Episode 29 : Reward -1.0
#
# Episode 30 : Reward -1.0
#
# Episode 31 : Reward 0.0
#
# Episode 32 : Reward 1.0
#
# Episode 33 : Reward 1.0
#
# Episode 34 : Reward -1.0
#
# Episode 35 : Reward 1.0
#
# Episode 36 : Reward -1.0
#
# Episode 37 : Reward 0.0
#
# Episode 38 : Reward -1.0
#
# Episode 39 : Reward 0.0
#
# Episode 40 : Reward -1.0
#
# Episode 41 : Reward 0.0
#
# Episode 42 : Reward -1.0
#
# Episode 43 : Reward -1.0
#
# Episode 44 : Reward -1.0
#
# Episode 45 : Reward -1.0
#
# Episode 46 : Reward 0.0
#
# Episode 47 : Reward -1.0
#
# Episode 48 : Reward -1.0
#
# Episode 49 : Reward 0.0
#
# Episode 50 : Reward -1.0
#
# Episode 51 : Reward 0.0
#
# Episode 52 : Reward -1.0
#
# Episode 53 : Reward 0.0
#
# Episode 54 : Reward 0.0
#
# Episode 55 : Reward -1.0
#
# Episode 56 : Reward -1.0
#
# Episode 57 : Reward -1.0
#
# Episode 58 : Reward -1.0
#
# Episode 59 : Reward 0.0
#
# Episode 60 : Reward -1.0
#
# Episode 61 : Reward -1.0
#
# Episode 62 : Reward -1.0
#
# Episode 63 : Reward -1.0
#
# Episode 64 : Reward -1.0
#
# Episode 65 : Reward -1.0
#
# Episode 66 : Reward 0.0
#
# Episode 67 : Reward -1.0
#
# Episode 68 : Reward -1.0
#
# Episode 69 : Reward -1.0
#
# Episode 70 : Reward 0.0
#
# Episode 71 : Reward -1.0
#
# Episode 72 : Reward 0.0
#
# Episode 73 : Reward -1.0
#
# Episode 74 : Reward -1.0
#
# Episode 75 : Reward -1.0
#
# Episode 76 : Reward -1.0
#
# Episode 77 : Reward 0.0
#
# Episode 78 : Reward 0.0
#
# Episode 79 : Reward -1.0
#
# Episode 80 : Reward -1.0
#
# Episode 81 : Reward 0.0
#
# Episode 82 : Reward -1.0
#
# Episode 83 : Reward 0.0
#
# Episode 84 : Reward -1.0
#
# Episode 85 : Reward 0.0
#
# Episode 86 : Reward 0.0
#
# Episode 87 : Reward -1.0
#
# Episode 88 : Reward 0.0
#
# Episode 89 : Reward -1.0
#
# Episode 90 : Reward -1.0
#
# Episode 91 : Reward 0.0
#
# Episode 92 : Reward -1.0
#
# Episode 93 : Reward -1.0
#
# Episode 94 : Reward -1.0
#
# Episode 95 : Reward -1.0
#
# Episode 96 : Reward 0.0
#
# Episode 97 : Reward -1.0
#
# Episode 98 : Reward -1.0
#
# Loss count: 0
# Total credit: 0
#
# Reward -43.5

# %%
'
# Out:
#   Cell In[235], line 1
#     '
#      ^
# SyntaxError: EOL while scanning string literal
